# %%
import os
import pandas as pd
from io import StringIO

from utils.pipeline import run_pipeline
# Configurable parameter: top_k (must be less than 15)
TOP_K = 1  # Adjust this as needed

# Paths
TESTSET_CSV_PATH = "/home/jaf/battery-lifespan-kg/eval/evaluator_question_short_6_value.csv"  # Update with your CSV file path
BATTERY_FILES_DIR = "/home/jaf/battery-lifespan-kg/resources/testset"

import re

def parse_response(response, top_k):
    """
    Parse the LLM response to extract a list of battery IDs using regex.
    Battery IDs are expected to be in the form "b{number}c{number}" (e.g., b1c1).
    
    :param response: The LLM response string.
    :param top_k: The maximum number of battery IDs to return.
    :return: A list of extracted battery IDs (up to top_k items).
    """
    try:
        # Regex pattern: word boundary, b followed by one or more digits,
        # c followed by one or more digits, then word boundary.
        pattern = r'\bb\d+c\d+\b'
        matches = re.findall(pattern, response, flags=re.IGNORECASE)
        # Normalize the matches (trim and lowercase)
        matches = [match.strip().lower() for match in matches]
        return matches[:top_k]
    except Exception as e:
        print(f"Error parsing response: {e}. Response was: {response}")
        return ['']


def normalize_str(s):
    return s.strip().lower()

def evaluate_testset():
    # Read the testset CSV
    df = pd.read_csv(TESTSET_CSV_PATH)
    
    total_comparisons = 0
    total_correct = 0
    
    # Iterate over each test case (row)
    for idx, row in df.iterrows():
        test_battery_id = row["TEST_BATTERY_ID"]
        battery_file_path = os.path.join(BATTERY_FILES_DIR, f"{test_battery_id}.txt")
        
        try:
            with open(battery_file_path, "r") as f:
                file_content = f.read()
        except Exception as e:
            print(f"Error reading file for battery {test_battery_id}: {e}")
            continue
        
        # Get expected battery IDs for positions 1 to TOP_K
        expected_ids = []
        for i in range(1, TOP_K+1):
            col_name = f"{i}_Most_Similar_Battery_ID"
            if col_name in row:
                expected_ids.append(str(row[col_name]).strip().lower())
            else:
                expected_ids.append("")  # In case the column is missing
        
        # Identify all sample question columns (e.g., SAMPLE_QUESTION_1, SAMPLE_QUESTION_2, etc.)
        sample_question_cols = [col for col in df.columns if col.startswith("SAMPLE_QUESTION")]
        
        # Evaluate each sample question as an individual data point
        for question_col in sample_question_cols:
            base_question = str(row[question_col]).strip()
            # Append instruction to force the list format with top-K results
            modified_question = (
                f"{base_question} return the top-{TOP_K} results from the most similar first. "
                "Please respond with a comma-separated list of battery IDs only."
            )
            
            # Create a file-like object from the file content
            from io import StringIO
            uploaded_file = StringIO(file_content)
            
            # Get LLM response
            response = run_pipeline(modified_question, uploaded_file)
            print(response)
            # print(response.keys())
            # Parse the response into a list of battery IDs
            if type(response) == str:
                extracted_ids = []
            else:
                extracted_ids = parse_response(response['result'], TOP_K)
            
            # Initialize score for this sample question
            sample_correct = 0
            for rank in range(TOP_K):
                total_comparisons += 1
                # If there is no candidate for this rank, count as not matched
                if rank >= len(extracted_ids):
                    print(f"Test case {test_battery_id}, question '{base_question}': Missing candidate at rank {rank+1}. Expected: {expected_ids[rank]}")
                    continue
                
                if normalize_str(extracted_ids[rank]) == normalize_str(expected_ids[rank]):
                    sample_correct += 1
                    total_correct += 1
                else:
                    print(f"Test case {test_battery_id}, question '{base_question}': Mismatch at rank {rank+1}. Expected: {expected_ids[rank]}, Got: {extracted_ids[rank]}")
            
            # Report score for this sample question
            accuracy = (sample_correct / TOP_K) * 100
            print(f"Test case {test_battery_id}, question '{base_question}' accuracy: {accuracy:.2f}%")
    
    overall_accuracy = (total_correct / total_comparisons) * 100 if total_comparisons > 0 else 0
    print(f"\nOverall accuracy across all sample questions: {overall_accuracy:.2f}%")

evaluate_testset()
# Out:
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Can you identify batteries that have a similar slope_last_10_cycles feature?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'The battery with a similar slope_last_10_cycles feature is b1c1.'}
# Test case b3c7, question ''Can you identify batteries that have a similar slope_last_10_cycles feature?'' accuracy: 100.00%
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: The property existence syntax `... exists(variable.property)` is no longer supported. Please use `variable.property IS NOT NULL` instead. (line 1, column 25 (offset: 24))
# "MATCH (b:Battery) WHERE EXISTS(b.slope_last_10_cycles) RETURN b.battery_id ORDER BY b.slope_last_10_cycles LIMIT 1"
#                          ^}. Returning empty response for scoring.
#
# Test case b3c7, question ''Are there any batteries that match a slope_last_10_cycles feature?'': Missing candidate at rank 1. Expected: b1c1
# Test case b3c7, question ''Are there any batteries that match a slope_last_10_cycles feature?'' accuracy: 0.00%
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Can you locate batteries with a comparable slope_last_10_cycles feature?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'The battery with a comparable slope_last_10_cycles feature is b1c1.'}
# Test case b3c7, question ''Can you locate batteries with a comparable slope_last_10_cycles feature?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'The battery with a similar mean_grad_last_1000_cycles to the unknown one is b1c1.'}
# Test case b3c7, question ''Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Could you identify batteries that match the mean_grad_last_1000_cycles of this particular battery?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'The battery that matches the mean_grad_last_1000_cycles of this particular battery is b1c1.'}
# Test case b3c7, question ''Could you identify batteries that match the mean_grad_last_1000_cycles of this particular battery?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Is it possible to locate batteries with a similar mean_grad_last_1000_cycles to this unknown battery?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'The battery with a similar mean_grad_last_1000_cycles to the unknown battery is b1c1.'}
# Test case b3c7, question ''Is it possible to locate batteries with a similar mean_grad_last_1000_cycles to this unknown battery?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Can you identify batteries that have a similar cycle to this one?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': "I'm sorry, but I don't have the information to identify batteries that have a similar cycle to this one."}
# Test case b3c7, question ''Can you identify batteries that have a similar cycle to this one?'': Missing candidate at rank 1. Expected: b1c0
# Test case b3c7, question ''Can you identify batteries that have a similar cycle to this one?'' accuracy: 0.00%
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Are there any batteries with a cycle similar to this one?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'b1c0'}
# Test case b3c7, question ''Are there any batteries with a cycle similar to this one?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.00023017525672912597\nmean_grad_last_10_cycles: -0.00022496283054351807\nslope_last_50_cycles: -0.0004295814037322998\nmean_grad_last_50_cycles: -0.00043808817863464353\nslope_last_100_cycles: -0.0004307425022125244\nmean_grad_last_100_cycles: -0.00043108373880386354\nslope_last_200_cycles: -0.0003900536894798279\nmean_grad_last_200_cycles: -0.00038991034030914305\nslope_last_300_cycles: -0.00035009324550628663\nmean_grad_last_300_cycles: -0.00035052637259165445\nslope_last_400_cycles: -0.0003128772974014282\nmean_grad_last_400_cycles: -0.00031308412551879885\nslope_last_500_cycles: -0.0002762656211853027\nmean_grad_last_500_cycles: -0.0002763822078704834\nslope_last_600_cycles: -0.00024240295092264812\nmean_grad_last_600_cycles: -0.00024246146281560262\nslope_last_700_cycles: -0.00021553754806518554\nmean_grad_last_700_cycles: -0.0002156040498188564\nslope_last_800_cycles: -0.0001955069601535797\nmean_grad_last_800_cycles: -0.00019555248320102692\nslope_last_900_cycles: -0.0001789477136400011\nmean_grad_last_900_cycles: -0.0001789929469426473\nslope_last_1000_cycles: -0.0001655479669570923\nmean_grad_last_1000_cycles: -0.00016554278135299684\ntotal_cycles: 1837', 'query': "'Could you locate batteries that have a comparable cycle to this one?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': "I'm sorry, but I don't have the information to provide a comparable battery to the one you mentioned."}
# Test case b3c7, question ''Could you locate batteries that have a comparable cycle to this one?'': Missing candidate at rank 1. Expected: b1c0
# Test case b3c7, question ''Could you locate batteries that have a comparable cycle to this one?'' accuracy: 0.00%
# {'schema': 'slope_last_10_cycles: -0.0004375815391540527\nmean_grad_last_10_cycles: -0.0004717111587524414\nslope_last_50_cycles: -0.000699530839920044\nmean_grad_last_50_cycles: -0.0007081651687622071\nslope_last_100_cycles: -0.0007300412654876709\nmean_grad_last_100_cycles: -0.0007338503003120422\nslope_last_200_cycles: -0.0006406581401824951\nmean_grad_last_200_cycles: -0.0006413722038269043\nslope_last_300_cycles: -0.0004850157101949056\nmean_grad_last_300_cycles: -0.00048515776793162026\nslope_last_400_cycles: -0.0003882008790969849\nmean_grad_last_400_cycles: -0.0003881929814815521\nslope_last_500_cycles: -0.0003251793384552002\nmean_grad_last_500_cycles: -0.00032526707649230957\nslope_last_600_cycles: -0.00028041601181030276\nmean_grad_last_600_cycles: -0.000280434787273407\nslope_last_700_cycles: -0.0002472104345049177\nmean_grad_last_700_cycles: -0.0002472308703831264\nslope_last_800_cycles: -0.0002214615046977997\nmean_grad_last_800_cycles: -0.00022154577076435088\nslope_last_900_cycles: -0.00020084804958767362\nmean_grad_last_900_cycles: -0.00020082573095957438\nslope_last_1000_cycles: -0.0001835176944732666\nmean_grad_last_1000_cycles: -0.00018351757526397706\ntotal_cycles: 1079', 'query': "'Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'b1c4'}
# Test case b3c10, question ''Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.0004375815391540527\nmean_grad_last_10_cycles: -0.0004717111587524414\nslope_last_50_cycles: -0.000699530839920044\nmean_grad_last_50_cycles: -0.0007081651687622071\nslope_last_100_cycles: -0.0007300412654876709\nmean_grad_last_100_cycles: -0.0007338503003120422\nslope_last_200_cycles: -0.0006406581401824951\nmean_grad_last_200_cycles: -0.0006413722038269043\nslope_last_300_cycles: -0.0004850157101949056\nmean_grad_last_300_cycles: -0.00048515776793162026\nslope_last_400_cycles: -0.0003882008790969849\nmean_grad_last_400_cycles: -0.0003881929814815521\nslope_last_500_cycles: -0.0003251793384552002\nmean_grad_last_500_cycles: -0.00032526707649230957\nslope_last_600_cycles: -0.00028041601181030276\nmean_grad_last_600_cycles: -0.000280434787273407\nslope_last_700_cycles: -0.0002472104345049177\nmean_grad_last_700_cycles: -0.0002472308703831264\nslope_last_800_cycles: -0.0002214615046977997\nmean_grad_last_800_cycles: -0.00022154577076435088\nslope_last_900_cycles: -0.00020084804958767362\nmean_grad_last_900_cycles: -0.00020082573095957438\nslope_last_1000_cycles: -0.0001835176944732666\nmean_grad_last_1000_cycles: -0.00018351757526397706\ntotal_cycles: 1079', 'query': "'Could you identify batteries that match the mean_grad_last_1000_cycles of this particular battery?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': "I'm sorry, but I don't have the necessary information to identify batteries that match the mean_grad_last_1000_cycles of the battery with ID 'b1c4'."}
# Test case b3c10, question ''Could you identify batteries that match the mean_grad_last_1000_cycles of this particular battery?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.0004375815391540527\nmean_grad_last_10_cycles: -0.0004717111587524414\nslope_last_50_cycles: -0.000699530839920044\nmean_grad_last_50_cycles: -0.0007081651687622071\nslope_last_100_cycles: -0.0007300412654876709\nmean_grad_last_100_cycles: -0.0007338503003120422\nslope_last_200_cycles: -0.0006406581401824951\nmean_grad_last_200_cycles: -0.0006413722038269043\nslope_last_300_cycles: -0.0004850157101949056\nmean_grad_last_300_cycles: -0.00048515776793162026\nslope_last_400_cycles: -0.0003882008790969849\nmean_grad_last_400_cycles: -0.0003881929814815521\nslope_last_500_cycles: -0.0003251793384552002\nmean_grad_last_500_cycles: -0.00032526707649230957\nslope_last_600_cycles: -0.00028041601181030276\nmean_grad_last_600_cycles: -0.000280434787273407\nslope_last_700_cycles: -0.0002472104345049177\nmean_grad_last_700_cycles: -0.0002472308703831264\nslope_last_800_cycles: -0.0002214615046977997\nmean_grad_last_800_cycles: -0.00022154577076435088\nslope_last_900_cycles: -0.00020084804958767362\nmean_grad_last_900_cycles: -0.00020082573095957438\nslope_last_1000_cycles: -0.0001835176944732666\nmean_grad_last_1000_cycles: -0.00018351757526397706\ntotal_cycles: 1079', 'query': "'Is it possible to locate batteries with a similar mean_grad_last_1000_cycles to this unknown battery?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': "I'm sorry, but I don't have the necessary information to provide the top-1 results of batteries with a similar mean_grad_last_1000_cycles to the battery with ID 'b1c4'."}
# Test case b3c10, question ''Is it possible to locate batteries with a similar mean_grad_last_1000_cycles to this unknown battery?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.0004375815391540527\nmean_grad_last_10_cycles: -0.0004717111587524414\nslope_last_50_cycles: -0.000699530839920044\nmean_grad_last_50_cycles: -0.0007081651687622071\nslope_last_100_cycles: -0.0007300412654876709\nmean_grad_last_100_cycles: -0.0007338503003120422\nslope_last_200_cycles: -0.0006406581401824951\nmean_grad_last_200_cycles: -0.0006413722038269043\nslope_last_300_cycles: -0.0004850157101949056\nmean_grad_last_300_cycles: -0.00048515776793162026\nslope_last_400_cycles: -0.0003882008790969849\nmean_grad_last_400_cycles: -0.0003881929814815521\nslope_last_500_cycles: -0.0003251793384552002\nmean_grad_last_500_cycles: -0.00032526707649230957\nslope_last_600_cycles: -0.00028041601181030276\nmean_grad_last_600_cycles: -0.000280434787273407\nslope_last_700_cycles: -0.0002472104345049177\nmean_grad_last_700_cycles: -0.0002472308703831264\nslope_last_800_cycles: -0.0002214615046977997\nmean_grad_last_800_cycles: -0.00022154577076435088\nslope_last_900_cycles: -0.00020084804958767362\nmean_grad_last_900_cycles: -0.00020082573095957438\nslope_last_1000_cycles: -0.0001835176944732666\nmean_grad_last_1000_cycles: -0.00018351757526397706\ntotal_cycles: 1079', 'query': "'Can you identify batteries that have a similar cycle to an unknown one?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': 'b1c5'}
# Test case b3c10, question ''Can you identify batteries that have a similar cycle to an unknown one?'' accuracy: 100.00%
# {'schema': 'slope_last_10_cycles: -0.0004375815391540527\nmean_grad_last_10_cycles: -0.0004717111587524414\nslope_last_50_cycles: -0.000699530839920044\nmean_grad_last_50_cycles: -0.0007081651687622071\nslope_last_100_cycles: -0.0007300412654876709\nmean_grad_last_100_cycles: -0.0007338503003120422\nslope_last_200_cycles: -0.0006406581401824951\nmean_grad_last_200_cycles: -0.0006413722038269043\nslope_last_300_cycles: -0.0004850157101949056\nmean_grad_last_300_cycles: -0.00048515776793162026\nslope_last_400_cycles: -0.0003882008790969849\nmean_grad_last_400_cycles: -0.0003881929814815521\nslope_last_500_cycles: -0.0003251793384552002\nmean_grad_last_500_cycles: -0.00032526707649230957\nslope_last_600_cycles: -0.00028041601181030276\nmean_grad_last_600_cycles: -0.000280434787273407\nslope_last_700_cycles: -0.0002472104345049177\nmean_grad_last_700_cycles: -0.0002472308703831264\nslope_last_800_cycles: -0.0002214615046977997\nmean_grad_last_800_cycles: -0.00022154577076435088\nslope_last_900_cycles: -0.00020084804958767362\nmean_grad_last_900_cycles: -0.00020082573095957438\nslope_last_1000_cycles: -0.0001835176944732666\nmean_grad_last_1000_cycles: -0.00018351757526397706\ntotal_cycles: 1079', 'query': "'Are there any batteries that share a similar cycle with an unknown one?' return the top-1 results from the most similar first. Please respond with a comma-separated list of battery IDs only.", 'result': "I'm sorry, but I don't have the information to answer that question."}
# Test case b3c10, question ''Are there any batteries that share a similar cycle with an unknown one?'': Missing candidate at rank 1. Expected: b1c5
# Test case b3c10, question ''Are there any batteries that share a similar cycle with an unknown one?'' accuracy: 0.00%
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '#': expected 'FOREACH', 'ALTER', 'ORDER BY', 'CALL', 'USING PERIODIC COMMIT', 'CREATE', 'LOAD CSV', 'START DATABASE', 'STOP DATABASE', 'DEALLOCATE', 'DELETE', 'DENY', 'DETACH', 'DROP', 'DRYRUN', 'FINISH', 'GRANT', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REALLOCATE', 'REMOVE', 'RENAME', 'RETURN', 'REVOKE', 'ENABLE SERVER', 'SET', 'SHOW', 'SKIP', 'TERMINATE', 'UNWIND', 'USE' or 'WITH' (line 1, column 1 (offset: 0))
# "# Assuming the similarity is based on the slope_last_500_cycles"
#  ^}. Returning empty response for scoring.
#
# Test case b3c10, question ''Can you locate batteries with a cycle similar to an unknown one?'': Missing candidate at rank 1. Expected: b1c5
# Test case b3c10, question ''Can you locate batteries with a cycle similar to an unknown one?'' accuracy: 0.00%
#
# Overall accuracy across all sample questions: 66.67%
